# %%
pip install confluent-kafka supabase
# Out:
# Collecting confluent-kafka
#   Downloading confluent_kafka-2.13.0-cp312-cp312-manylinux_2_28_aarch64.whl.metadata (32 kB)
# Collecting supabase
#   Downloading supabase-2.28.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting realtime==2.28.0 (from supabase)
#   Downloading realtime-2.28.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.28.0 (from supabase)
#   Downloading supabase_functions-2.28.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.28.0 (from supabase)
#   Downloading storage3-2.28.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting supabase-auth==2.28.0 (from supabase)
#   Downloading supabase_auth-2.28.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.28.0 (from supabase)
#   Downloading postgrest-2.28.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in /databricks/python3/lib/python3.12/site-packages (from supabase) (0.27.0)
# Collecting yarl>=1.22.0 (from supabase)
#   Downloading yarl-1.22.0-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (75 kB)
# Collecting deprecation>=2.1.0 (from postgrest==2.28.0->supabase)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /databricks/python3/lib/python3.12/site-packages (from postgrest==2.28.0->supabase) (2.10.6)
# Collecting pydantic<3.0,>=1.9 (from postgrest==2.28.0->supabase)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing-extensions>=4.14.0 (from realtime==2.28.0->supabase)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting websockets<16,>=11 (from realtime==2.28.0->supabase)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (6.8 kB)
# Collecting pyiceberg>=0.10.0 (from storage3==2.28.0->supabase)
#   Downloading pyiceberg-0.11.0-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (4.8 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in /databricks/python3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (2.10.1)
# Collecting strenum>=0.4.15 (from supabase-functions==2.28.0->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (4.6.2)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (1.0.2)
# Requirement already satisfied: idna in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (3.7)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.14.0)
# Collecting multidict>=4.0 (from yarl>=1.22.0->supabase)
#   Downloading multidict-6.7.1-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.1 (from yarl>=1.22.0->supabase)
#   Downloading propcache-0.4.1-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from deprecation>=2.1.0->postgrest==2.28.0->supabase) (24.1)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (0.7.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase)
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (5.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.32.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (8.1.7)
# Requirement already satisfied: rich<15.0.0,>=10.11.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (13.9.4)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (1.7.3)
# Requirement already satisfied: fsspec>=2023.1.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2023.5.0)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (3.2.0)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (9.0.0)
# Collecting pyroaring<2.0.0,>=1.0.0 (from pyiceberg>=0.10.0->storage3==2.28.0->supabase)
#   Downloading pyroaring-1.0.3-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (10 kB)
# Requirement already satisfied: cachetools<7.0,>=5.5 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (5.5.1)
# Requirement already satisfied: zstandard<1.0.0,>=0.13.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (0.23.0)
# Requirement already satisfied: cryptography>=3.4.0 in /databricks/python3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (1.17.1)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /databricks/python3/lib/python3.12/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.12/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.15.1)
# Requirement already satisfied: python-dateutil>=2.6.0 in /databricks/python3/lib/python3.12/site-packages (from strictyaml<2.0.0,>=1.7.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.9.0.post0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (0.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.6.0->strictyaml<2.0.0,>=1.7.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (1.16.0)
# Downloading confluent_kafka-2.13.0-cp312-cp312-manylinux_2_28_aarch64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 65.9 MB/s eta 0:00:00
# Downloading supabase-2.28.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.28.0-py3-none-any.whl (22 kB)
# Downloading realtime-2.28.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.28.0-py3-none-any.whl (28 kB)
# Downloading supabase_auth-2.28.0-py3-none-any.whl (48 kB)
# Downloading supabase_functions-2.28.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (372 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading multidict-6.7.1-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (258 kB)
# Downloading propcache-0.4.1-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (225 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.9 MB/s eta 0:00:00
# Downloading pyiceberg-0.11.0-cp312-cp312-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (729 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.3/729.3 kB 34.4 MB/s eta 0:00:00
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (183 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading pyroaring-1.0.3-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 38.4 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: strenum, pyroaring, websockets, typing-extensions, propcache, multidict, hyperframe, hpack, deprecation, confluent-kafka, yarl, typing-inspection, pydantic-core, h2, pydantic, supabase-functions, supabase-auth, realtime, pyiceberg, postgrest, storage3, supabase
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-056598c6-c2e1-47ee-89c2-0ee0df7456cf
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Not uninstalling pydantic-core at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-056598c6-c2e1-47ee-89c2-0ee0df7456cf
#     Can't uninstall 'pydantic_core'. No files were found to uninstall.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Not uninstalling pydantic at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-056598c6-c2e1-47ee-89c2-0ee0df7456cf
#     Can't uninstall 'pydantic'. No files were found to uninstall.
#   Attempting uninstall: pyiceberg
#     Found existing installation: pyiceberg 0.9.0
#     Not uninstalling pyiceberg at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-056598c6-c2e1-47ee-89c2-0ee0df7456cf
#     Can't uninstall 'pyiceberg'. No files were found to uninstall.
# Successfully installed confluent-kafka-2.13.0 deprecation-2.1.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 multidict-6.7.1 postgrest-2.28.0 propcache-0.4.1 pydantic-2.12.5 pydantic-core-2.41.5 pyiceberg-0.11.0 pyroaring-1.0.3 realtime-2.28.0 storage3-2.28.0 strenum-0.4.15 supabase-2.28.0 supabase-auth-2.28.0 supabase-functions-2.28.0 typing-extensions-4.15.0 typing-inspection-0.4.2 websockets-15.0.1 yarl-1.22.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS invistis;
CREATE SCHEMA IF NOT EXISTS invistis.datalake;
CREATE VOLUME IF NOT EXISTS invistis.datalake.raw;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
SUPABASE_HOST = "https://dtbhervknmfsgrfzbkxm.supabase.co" # ton host Supabase
SUPABASE_PORT = "5432"
SUPABASE_DB   = "postgres"
SUPABASE_USER = "postgres"
SUPABASE_PASSWORD = "#Ex9_x3kR7/k7NJ"

supabase_url = f"jdbc:postgresql://{SUPABASE_HOST}:{SUPABASE_PORT}/{SUPABASE_DB}"

supabase_props = {
    "user": SUPABASE_USER,
    "password": SUPABASE_PASSWORD,
    "driver": "org.postgresql.Driver",
    "sslmode": "require"
}

# %%
CONFLUENT_BOOTSTRAP = "pkc-921jm.us-east-2.aws.confluent.cloud:9092"
CONFLUENT_API_KEY   = "JWVBQ7RG25AVCHHY"
CONFLUENT_SECRET    = "cflt9aP2o4QFY2CAugnhB/J/MMhEIDYtyGdj3Gu6dcFih68+sqYqyvBvzj8ABd4g"

CHECKPOINT_PATH = "/Volumes/invistis/datalake/raw/checkpoints"
DATA_PATH       = "/Volumes/invistis/datalake/raw/enriched"

kafka_options = {
    "kafka.bootstrap.servers": CONFLUENT_BOOTSTRAP,
    "kafka.sasl.mechanism": "PLAIN",
    "kafka.security.protocol": "SASL_SSL",
    "kafka.sasl.jaas.config": f'kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{CONFLUENT_API_KEY}" password="{CONFLUENT_SECRET}";',
    "startingOffsets": "earliest",
    "failOnDataLoss": "false"
}
print("✅ Config OK")
# Out:
# ✅ Config OK

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

trades_schema = StructType([
    StructField("symbol", StringType()),
    StructField("price", DoubleType()),
    StructField("quantity", DoubleType()),
    StructField("timestamp", LongType()),
    StructField("trade_id", StringType()),
])

trades_df = (spark.readStream
    .format("kafka")
    .options(**kafka_options)
    .option("subscribe", "trades_topic")
    .load()
    .select(from_json(col("value").cast("string"), trades_schema).alias("data"), "timestamp")
    .select("data.*", col("timestamp").alias("kafka_ts"))
    .withColumn("event_time", to_timestamp(col("timestamp") / 1000))
    .withWatermark("event_time", "5 minutes")
)
print("✅ Trades stream OK")
# Out:
# ✅ Trades stream OK

# %%
news_schema = StructType([
    StructField("title", StringType()),
    StructField("description", StringType()),
    StructField("source", StringType()),
    StructField("published_at", StringType()),
    StructField("sentiment", DoubleType()),
])

news_df = (spark.readStream
    .format("kafka")
    .options(**kafka_options)
    .option("subscribe", "news_topic")
    .load()
    .select(from_json(col("value").cast("string"), news_schema).alias("data"), "timestamp")
    .select("data.*", col("timestamp").alias("kafka_ts"))
    .withColumn("event_time", to_timestamp(col("published_at")))
    .withColumn("symbol", lit("BTCUSDT"))
    .withWatermark("event_time", "5 minutes")
)
print("✅ News stream OK")
# Out:
# ✅ News stream OK

# %%
from pyspark.sql.functions import *

# Stream-to-Stream Join avec fenêtre plus large
joined_df = trades_df.alias("t").join(
    news_df.alias("n"),
    expr("""
        t.symbol = n.symbol AND
        t.event_time BETWEEN n.event_time - INTERVAL 24 HOURS
        AND n.event_time + INTERVAL 24 HOURS
    """),
    "left"
).select(
    col("t.symbol"),
    col("t.price"),
    col("t.quantity"),
    col("t.event_time").alias("trade_time"),
    col("n.title").alias("news_title"),
    col("n.sentiment"),
    col("n.event_time").alias("news_time"),
    window(col("t.event_time"), "5 minutes").alias("window_5min")
)

# Paths
CHECKPOINT_PATH = "/Volumes/invistis/datalake/raw/checkpoints"
DATA_PATH = "/Volumes/invistis/datalake/raw/enriched"

# Sink 1 : Delta Lake
query_lake = (joined_df.writeStream
    .format("delta")
    .outputMode("append")
    .option("checkpointLocation", f"{CHECKPOINT_PATH}/lake2")
    .option("path", DATA_PATH)
    .trigger(availableNow=True)
    .start()
)

query_lake.awaitTermination()
print("✅ Done!")
# Out:
# ✅ Done!

# %%
# Supprimer l'ancienne table pour repartir propre
dbutils.fs.rm("/Volumes/invistis/datalake/raw/enriched", recurse=True)
dbutils.fs.rm("/Volumes/invistis/datalake/raw/checkpoints/lake_v3", recurse=True)
print("✅ Ancienne table supprimée")
# Out:
# ✅ Ancienne table supprimée

# %%
query_lake = (joined_df
    .writeStream
    .format("delta")
    .outputMode("append")
    .option("checkpointLocation", f"{CHECKPOINT_PATH}/lake_v4")
    .option("path", DATA_PATH)
    .foreachBatch(lambda df, epoch_id: 
        df.select(
            col("symbol"),
            col("price"),
            col("quantity"),
            col("trade_time"),
            col("news_title"),
            col("sentiment"),
            col("news_time"),
            window(col("trade_time"), "5 minutes").getField("start").alias("window_start"),
            window(col("trade_time"), "5 minutes").getField("end").alias("window_end")
        ).write.format("delta").mode("append").save(DATA_PATH)
    )
    .trigger(availableNow=True)
    .start()
)

query_lake.awaitTermination()
print("✅ Stream-to-Stream Join + Delta Lake OK !")
# Out:
# ✅ Stream-to-Stream Join + Delta Lake OK !

# %%
# Sauvegarder avec overwriteSchema
joined_batch.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save(DATA_PATH)

# Afficher
df = spark.read.format("delta").load(DATA_PATH)
print(f"✅ Total rows: {df.count()}")
display(df.limit(20))
# Out:
# ✅ Total rows: 3993
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>symbol</th><th>price</th><th>quantity</th><th>trade_time</th><th>news_title</th><th>sentiment</th><th>news_time</th><th>window_5min</th></tr></thead><tbody><tr><td>BTCUSDT</td><td>63224.1</td><td>2.0E-4</td><td>2026-02-24T12:11:28.796Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>1.7E-4</td><td>2026-02-24T12:11:29.935Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>0.00326</td><td>2026-02-24T12:11:29.935Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>0.02086</td><td>2026-02-24T12:11:29.935Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>1.7E-4</td><td>2026-02-24T12:11:31.727Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>8.0E-5</td><td>2026-02-24T12:11:31.727Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>6.9E-4</td><td>2026-02-24T12:11:31.727Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>4.8E-4</td><td>2026-02-24T12:11:31.727Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>4.7E-4</td><td>2026-02-24T12:11:31.727Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.11</td><td>0.00764</td><td>2026-02-24T12:11:32.176Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>0.00266</td><td>2026-02-24T12:11:32.303Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>8.1E-4</td><td>2026-02-24T12:11:32.547Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>0.00476</td><td>2026-02-24T12:11:32.738Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>0.03062</td><td>2026-02-24T12:11:33.382Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>0.00759</td><td>2026-02-24T12:11:34.491Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>9.9E-4</td><td>2026-02-24T12:11:34.984Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>2.3E-4</td><td>2026-02-24T12:11:35.461Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.11</td><td>8.1E-4</td><td>2026-02-24T12:11:35.918Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>2.6E-4</td><td>2026-02-24T12:11:37.813Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-24T12:10:00.000Z, 2026-02-24T12:15:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>63224.1</td><td>8.0E-4</t ...

# %%
import requests
import json
import numpy as np
import pandas as pd

def clean_record(row):
    record = {}
    for k, v in row.items():
        if v is None:
            record[k] = None
        elif isinstance(v, float) and np.isnan(v):
            record[k] = None
        elif isinstance(v, pd.NaT.__class__) or v is pd.NaT:
            record[k] = None
        elif hasattr(v, 'isoformat'):  # datetime/timestamp → string ISO
            record[k] = v.isoformat()
        elif isinstance(v, np.integer):
            record[k] = int(v)
        elif isinstance(v, np.floating):
            record[k] = None if np.isnan(v) else float(v)
        else:
            record[k] = v
    return record

# Remplacer tous les NaT par None AVANT la boucle
pdf_clean = pdf.where(pdf.notna(), None)

records = [clean_record(row) for _, row in pdf_clean.iterrows()]

# Vérification sur 1 record
print("Sample record:", json.dumps(records[0], default=str))

# Envoi
BATCH_SIZE = 500
success = 0

for i in range(0, len(records), BATCH_SIZE):
    batch = records[i:i+BATCH_SIZE]
    response = requests.post(
        f"{SUPABASE_URL}/rest/v1/enriched_trades",
        headers=headers,
        data=json.dumps(batch)
    )
    if response.status_code in [200, 201]:
        success += len(batch)
        print(f"✅ Batch {i//BATCH_SIZE + 1} envoyé ({success}/{len(records)})")
    else:
        print(f"❌ Erreur: {response.status_code} - {response.text}")

print(f"✅ Total envoyé : {success} lignes !")
# Out:
# Sample record: {"symbol": "BTCUSDT", "price": 63224.1, "quantity": 0.0002, "trade_time": "2026-02-24T12:11:28.796000", "news_title": null, "sentiment": null, "news_time": null, "window_start": "2026-02-24T12:10:00", "window_end": "2026-02-24T12:15:00"}
# ✅ Batch 1 envoyé (500/3993)
# ✅ Batch 2 envoyé (1000/3993)
# ✅ Batch 3 envoyé (1500/3993)
# ✅ Batch 4 envoyé (2000/3993)
# ✅ Batch 5 envoyé (2500/3993)
# ✅ Batch 6 envoyé (3000/3993)
# ✅ Batch 7 envoyé (3500/3993)
# ✅ Batch 8 envoyé (3993/3993)
# ✅ Total envoyé : 3993 lignes !
